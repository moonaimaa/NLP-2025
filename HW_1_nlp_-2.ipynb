# %% [markdown]
# # Pandas: Work with lines! — SOLUTION
#
# This notebook completes the homework using the provided CSV files.

# %% [markdown]
# ## Step 1 — Loading data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH_DIR = "/content/drive/MyDrive/Colab Notebooks"

# %%
import os
import pandas as pd

# %%
def load_data(filename: str, drop_unnamed=True):
    if not os.path.exists(filename):
        print(f"{filename} does not exist")
        return None
    try:
        df = pd.read_csv(filename)
    except Exception:
        df = pd.read_csv(filename, sep=';')
    if drop_unnamed and "Unnamed: 0" in df.columns:
        df = df.drop(columns=["Unnamed: 0"])
    return df

# %%
missing_path = os.path.join(PATH_DIR, "SocialNetworkAds.csv")
data = load_data(missing_path)
# Out:
# /content/drive/MyDrive/Colab Notebooks/SocialNetworkAds.csv does not exist

# %%
print(data)
# Out:
# None

# %%
str_csv_name = "dirty_str_house_prices.csv"
filename = os.path.join(PATH_DIR, str_csv_name)
pd_data = load_data(filename)

# %%
if pd_data is not None:
    pd.set_option("display.max_columns", None)
    pd.set_option("display.width", 200)

    print("\nСписок столбцов:")
    print(pd_data.columns.values.tolist())

    print("\nПервые 5 строк:")
    print(pd_data.head())

    print("\nПоследние 5 строк:")
    print(pd_data.tail())
else:
    print("\nНе удалось загрузить датасет — проверь путь и имя файла.")
# Out:
# Список столбцов:
# ['Id', 'MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']
#
# Первые 5 строк:
#    Id MSZoning  Street LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  RoofStyle     RoofMatl    Exterior1st Exterior2nd MasVnrType  \
# 0   1      rl:   PAVE.     ;REg       \tlvl   AllPub.   InsidE:      gtl      COLLGCR<      norm;      NORM.     1fam   ?2story?   GABLE...     compshg!  ...Vinylsd...    Vinylsd.   Brkface>
# 1   2    ...RL   <PAVE    reg\t        Lvl;  AllPUb\t      FR2       Gtl<    veenker\t    ?FEedr.      ;norm    1FAM:    :1story  .GABLE...     CoMPSHG>        METALSD    metalsd      ?NOnE.
# 2   3     ;Rl    Pave      ir1?        LVL!   Allpub!  ?inside     ...Gtl     ?COLLGCR      !Norm     .norm>    !1fam    .2story      Gable  ...COMPSHG:       vinylsd.    ?Vinylsd   !brkface
# 3   4       rl   pave.     ;IR1        .Lvl  ;ALLPUB;   >Corner      ;GTL     .CRAWFOR       NORm      NORM:    1FAM>    2STORY<   \tgable.    !Compshg<       WD SDNG:    Wd shng;      :NONE
# 4   5    .rl\t  PaVE\t   Ir1...        Lvl<   !Allpub      ?fr2   .GTL...    ?NoRIdge>   ...NORM<      Norm;    1fam<    2SToRy<     GaBLe<     :compshg       :VINYLSD    VInYLSD?   ?Brkface
#
#   ExterQual ExterCond    Foundation BsmtQual  BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2    Heating HeatingQC CentralAir Electrical KitchenQual Functional GarageType GarageFinish GarageQual  \
# 0     GD...       TA<        pconc>    \tGd>       :TA        .no\t        ;Glq          UNF.      GASA<      \tEX         :Y     SBRKr         gd\t        TYP    AttChd<         .RFn       TA\t
# 1      ?Ta<        TA       >Cblock    ?GD\t       TA:           gd          Alq         ;Unf     ;GASA:       Ex         y\t    \tSBRKR         ta?       ;TYP    Attchd>        RFn\t       \tTa
# 2        gd       !TA       \tPCOnC     ;GD.      .TA          mn\t          GLQ       \tUNF;    GAsA...       ;Ex        Y\t     sbrkr<         .Gd     TyP...    Attchd;         ;RFN    \tTA...
# 3       Ta<      TA\t  ...BRKTIL...     .Ta       \tgd         >NO:          alq        :unf<     GaSA\t      :GD        Y...    \tSbrkr         Gd<       !TYP  DETCHD...         UNF?      \tTa;
# 4       :Gd       ta:       .pconc:     <Gd<  ...TA...           Av        ;glq!      :unf...  \tGASA...       ex!          y    \tSbrkr         GD;      <Typ>   Attchd\t        !rfn>       TA\t
#
#   GarageCond PavedDrive SaleType SaleCondition
# 0      \tTA<         y?      wd      \tNormal?
# 1      >TA\t        ;Y!      Wd        Normal.
# 2        TA           Y      WD;        NORMAL
# 3        ;Ta         .Y      wd.     ABNORML\t
# 4         Ta       \tY>     ?WD!       NoRmAl>
#
# Последние 5 строк:
#         Id MSZoning  Street LotShape LandContour Utilities   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  HouseStyle RoofStyle    RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1333  1456      ?rl   PAVE>   ...Reg       >LVL<  Allpub\t  ...INSIDe:      GTL;   \tGilbert:      Norm?       NORM    ?1fam      2story     gable   COMPSHG\t   >ViNyLSD!    VINyLSD<       none
# 1334  1457      Rl<   <PAVE      REG      ...lvl   Allpub:     .INsIDE      Gtl.    ...NWAMEs    NORM...     \tnorm    1fam>  ;1STORY...     GaBle    COMPSHG.  Plywood...    <PlyWOOD    !Stone>
# 1335  1458      ?RL   Pave!   ...Reg        >LVL   AlLPUb.     !InSiDE      >GTl    >CRAWfoR<       Norm    Norm...   1fam\t      2story    .gable  \tCOMPSHG;    Cemntbd!    cmentbd:     >None<
# 1336  1459     RL\t   PAvE<     reg;      ?lvl\t   .AlLPUb     Inside:      :Gtl        names       norm    \tnorm.   ;1FAM   ;1StoRY...      ;HIP    COMPSHG.    Metalsd.     Metalsd      NONE:
# 1337  1460     .rl!  <Pave:     Reg;     ...LVL?  .AlLPUb      INsIDe.    gtl...    \tEdwards    !NORM\t      norm?   !1fam<   1story...    <gable    ;Compshg   hdboard\t   ?HDBOaRD       None?
#
#      ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  Heating HeatingQC CentralAir Electrical KitchenQual Functional GarageType GarageFinish GarageQual  \
# 1333       .ta     TA...    <pconc!      <GD      ta:          ?NO          Unf         Unf<     gasa     EX...         >Y     >sbrkr         .ta       !TYP    ;Attchd         :RFn        TA<
# 1334       >TA       TA!  ...CBLOCK       GD    \tTA:          ;NO         >ALQ         Rec:    .GaSA       :TA         !y      SBRKR         TA!      MIn1?    ATTCHD<         :unf       >Ta>
# 1335       ;EX      :gd:     .Stone       Ta      ?Gd         <NO:       GLQ...         unf<    Gasa.        ex         :y     Sbrkr;         !Gd       :TyP    AttChD<         ?Rfn        >TA
# 1336       Ta.       Ta     CBLOcK?      :TA      TA?         ?mn;          Glq         rec:  :GAsA\t       Gd.         ?Y   \tFUseA:         Gd!        TYP    attchd.          Unf       :Ta;
# 1337       <Gd       !TA  CBLOCK...      ;TA       TA          NO.          blq         LWQ!  \tGASA!     \tGd<        ;Y!    ;SBRKR?        ;ta:       typ:    .ATTCHD          FIn       >ta?
#
#      GarageCond PavedDrive SaleType SaleCondition
# 1333        :Ta         Y;      Wd?     normal...
# 1334        ?TA       >Y\t      Wd;     \tNormal;
# 1335       :TA:         .Y     >wd!      :NORMAL;
# 1336       \tTA       ...Y     <WD!       :normal
# 1337      \tta<      >y...      Wd;       ;NORMAL

# %% [markdown]
# ## Step 2 — Group counts for categorical columns

# %%
import os
import pandas as pd

try:
    pd_data
except NameError:
    PATH_DIR = "/content/drive/MyDrive/data"
    filename = os.path.join(PATH_DIR, "dirty_str_house_prices.csv")

    def load_data(filename: str):
        if not os.path.exists(filename):
            print(f"{filename} does not exist")
            return None
        try:
            return pd.read_csv(filename)
        except Exception:
            return pd.read_csv(filename, sep=';')
    pd_data = load_data(filename)

def count_by_group(data, column=""):
    if data is None:
        return {}
    if column and column in data.columns:
        return data[column].value_counts()
    obj_cols = [c for c in data.columns if data[c].dtype == 'object']
    result = {}
    for c in obj_cols:
        result[c] = data[c].value_counts()
    return result

result = count_by_group(data=pd_data, column="")
print(type(result))
print(result)

print("\n\n=== Пример: распределение значений в колонке 'LotShape' ===")
result_lotshape = count_by_group(data=pd_data, column="LotShape")
print(type(result_lotshape))
print(result_lotshape)
# Out:
# <class 'dict'>
# {'MSZoning': MSZoning
# RL      42
# RL<     30
# RL.     24
# >RL     22
# RL!     21
#         ..
# >RL!     1
# <Rm      1
# :RM!     1
# <rm<     1
# <Rl>     1
# Name: count, Length: 410, dtype: int64, 'Street': Street
# PAVE        22
# Pave        20
# pave        20
# >pave       19
# Pave...     19
#             ..
# ;pave!       1
# ...Pave      1
# ;PaVe        1
#  PAvE        1
# ...PAvE>     1
# Name: count, Length: 428, dtype: int64, 'LotShape': LotShape
# REG          18
# Reg          17
#  IR1         14
# Reg<         14
# !REG         14
#              ..
#  Ir1...       1
# ;reg.         1
# ir2\t         1
# ?reg...       1
# ...REG...     1
# Name: count, Length: 480, dtype: int64, 'LandContour': LandContour
# Lvl        27
# LVL        25
# lvl        22
# LVL.       19
# >Lvl       18
#            ..
# ...LvL      1
# \tLvl<      1
# .Low\t      1
# LOw\t       1
# Hls.        1
# Name: count, Length: 456, dtype: int64, 'Utilities': Utilities
# allpub      29
# ALLPUB      23
# ALLPUB      19
# ALLPUB;     19
# Allpub:     17
#             ..
# AlLPUB;      1
#  ALlPuB>     1
# :AlLPub:     1
# AlLPUB\t     1
# AllPub.      1
# Name: count, Length: 501, dtype: int64, 'LotConfig': LotConfig
# inside         18
# Inside:        18
# >Inside        16
# INSIDE         16
# <inside        14
#                ..
# culdsac\t       1
#  InSIDE         1
# >corner...      1
# ...CUlDSac?     1
# !inside>        1
# Name: count, Length: 695, dtype: int64, 'LandSlope': LandSlope
# GTL         24
# gtl         23
#  GTL        19
# Gtl         19
# GTL:        18
#             ..
# :gtl:        1
# :gtl>        1
# ...Gtl\t     1
# !gtl!        1
# <gtl?        1
# Name: count, Length: 398, dtype: int64, 'Neighborhood': Neighborhood
# NAMES         10
# Names?         6
# ?COLLGCR       6
# Nwames         5
# NAMES          5
#               ..
# brdale!        1
# EdwaRDs\t      1
# NPKVILL        1
# .SawyeRW:      1
# NRIDGHT...     1
# Name: count, Length: 1111, dtype: int64, 'Condition1': Condition1
# Norm       21
# NORM...    17
# ?Norm      17
# norm\t     16
#  Norm      16
#            ..
# >NORM!      1
# ;rrae       1
# Feedr<      1
# !NOrm;      1
# :NORM;      1
# Name: count, Length: 549, dtype: int64, 'Condition2': Condition2
# norm        27
# >Norm       22
# norm<       20
# !NORM       20
# <NORM       19
#             ..
# !norm>       1
# ?norm>       1
# !NORM?       1
# ;rrae...     1
# >NoRm!       1
# Name: count, Length: 412, dtype: int64, 'BldgType': BldgType
# 1fam          49
# 1fam>         30
# :1fam         24
# 1fam<         23
# 1fam          22
#               ..
# .TWNhSE?       1
# >Twnhse...     1
# twnhse;        1
#  1FAM:         1
# <1FAM?         1
# Name: count, Length: 441, dtype: int64, 'HouseStyle': HouseStyle
# 1story         27
# 2story         16
# !1story        16
# 1story.        15
# 1story         15
#                ..
# ?1StOry         1
# \t2story...     1
#  1STOrY>        1
#  1.5FIN:        1
# ...1.5FIN.      1
# Name: count, Length: 662, dtype: int64, 'RoofStyle': RoofStyle
# GABLE      20
# !GABLE     15
# GABLE\t    14
# GABLE?     14
# gable      14
#            ..
# >GaBle?     1
# ;hip?       1
#  gable!     1
#  hip;       1
# .GaBLe;     1
# Name: count, Length: 583, dtype: int64, 'RoofMatl': RoofMatl
# COMPSHG.       24
# COMPSHG        22
# \tCOMPSHG      18
# \tCompshg      17
# ...COMPSHG     17
#                ..
# :COMpShG.       1
# CompShg!        1
# ComPShG>        1
# ?COMpShg...     1
# :COMPSHg;       1
# Name: count, Length: 545, dtype: int64, 'Exterior1st': Exterior1st
# Vinylsd;     9
# vinylsd      9
# vinylsd.     8
# VINYLSD      8
# Vinylsd      8
#             ..
# Wd SdnG<     1
# VINylSd      1
#  cemntbd<    1
# >HDBOARD?    1
# .VINylSD:    1
# Name: count, Length: 889, dtype: int64, 'Exterior2nd': Exterior2nd
# VINYLSD       11
# vinylsd        9
# Vinylsd        9
# Wd sdng        8
# vinylsd<       7
#               ..
# .Wd shng       1
# !VinYlSd       1
# Plywood\t      1
# \tAsbShNg:     1
# ?VINYLSD:      1
# Name: count, Length: 902, dtype: int64, 'MasVnrType': MasVnrType
# None\t     15
# none       14
# \tNone     13
# NONE       12
# None<      12
#            ..
# <StoNe      1
# ?stone.     1
# NoNE!       1
# ?NOnE.      1
# >None<      1
# Name: count, Length: 649, dtype: int64, 'ExterQual': ExterQual
# TA        29
# TA.       18
# .TA       18
# TA:       17
# ta        17
#           ..
# :GD...     1
#  Ta<       1
# <ta>       1
# ?TA?       1
#  Ta.       1
# Name: count, Length: 445, dtype: int64, 'ExterCond': ExterCond
# TA       31
# TA...    26
# TA:      26
# TA?      24
# Ta       23
#          ..
#  Gd       1
# ?TA!      1
# !TA!      1
# >ta\t     1
# :gd:      1
# Name: count, Length: 363, dtype: int64, 'Foundation': Foundation
# Cblock        14
# PCONC         13
# :cblock       11
# PCONC\t       11
# CBLOCK        11
#               ..
# ...BRKTIL:     1
# :PConc!        1
# BrkTIL:        1
# PConc:         1
# ;CBloCK>       1
# Name: count, Length: 689, dtype: int64, 'BsmtQual': BsmtQual
# TA        17
# TA>       17
# GD        16
# Gd        16
# Gd...     15
#           ..
# ;Gd!       1
# \tTa\t     1
# ?Ta?       1
# !EX?       1
# ?Gd!       1
# Name: count, Length: 472, dtype: int64, 'BsmtCond': BsmtCond
# TA        31
# TA...     29
# ?TA       28
# :TA       26
# TA!       24
#           ..
# ;Ta...     1
# >GD\t      1
# ;TA.       1
#  Ta...     1
# \tTA:      1
# Name: count, Length: 348, dtype: int64, 'BsmtExposure': BsmtExposure
# No        21
#  NO       19
#  No       17
# !NO       17
# No>       16
#           ..
# .No?       1
# ?no!       1
# \tno\t     1
# ...GD:     1
# ...no      1
# Name: count, Length: 489, dtype: int64, 'BsmtFinType1': BsmtFinType1
# GLQ      15
# GLQ      13
# GLQ.     13
# ALQ      11
# UNF      11
#          ..
# ;Glq      1
# ?GLQ<     1
# .GLQ?     1
# ALQ.      1
# blq.      1
# Name: count, Length: 649, dtype: int64, 'BsmtFinType2': BsmtFinType2
# unf        22
# Unf        21
# Unf!       19
# UNF        18
# .Unf       17
#            ..
# !unf!       1
# ...UNF      1
# :unf.       1
# Lwq?        1
# REC>        1
# Name: count, Length: 464, dtype: int64, 'Heating': Heating
# gasa        26
# GASA        22
# \tGASA      19
# GASA<       19
# ;Gasa       18
#             ..
# \tGasA;      1
# ...GaSA<     1
# Othw.        1
# \tGasA!      1
# !Gasa        1
# Name: count, Length: 400, dtype: int64, 'HeatingQC': HeatingQC
# EX      17
# EX      15
# ex      13
# ?Ex     13
# Ex\t    13
#         ..
# <FA      1
# ;ta>     1
# ?Ex;     1
# >Ex>     1
# >Ex      1
# Name: count, Length: 502, dtype: int64, 'CentralAir': CentralAir
# Y        76
# Y        46
# .Y       42
#  Y       40
# ;Y       38
#          ..
# ...N;     1
# !Y;       1
#  y        1
#  N!       1
# <n        1
# Name: count, Length: 229, dtype: int64, 'Electrical': Electrical
# SBRKR      19
# Sbrkr      19
# ?Sbrkr     17
# SBRKR!     16
# !Sbrkr     16
#            ..
# :sbrkr!     1
# ?SBRkr      1
# >sbrkr      1
# .Sbrkr<     1
#  SBRKR<     1
# Name: count, Length: 524, dtype: int64, 'KitchenQual': KitchenQual
# :TA      18
# Gd       18
# <TA      16
# ;TA      15
# TA<      15
#          ..
# >Ta!      1
# ?Gd;      1
# \tGD;     1
# \tTA!     1
# <FA       1
# Name: count, Length: 470, dtype: int64, 'Functional': Functional
# TYP        37
# Typ        22
# typ;       21
# TYP!       20
# <TYP       19
#            ..
#  Typ...     1
# :Min1       1
# !Typ:       1
# Min2>       1
# MIn1?       1
# Name: count, Length: 408, dtype: int64, 'GarageType': GarageType
# attchd         15
# Attchd>        14
# Attchd\t       13
# \tattchd       12
# ATTCHD?        12
#                ..
# \tATtchd;       1
# BuiltIN;        1
# \tDETCHD...     1
# >DeTcHd:        1
# ;BuIltIN        1
# Name: count, Length: 668, dtype: int64, 'GarageFinish': GarageFinish
# UNF!       13
# Unf>       12
# .UNF       10
# UNF        10
# UNF        10
#            ..
# UnF;        1
# .RFN>       1
# >FiN        1
# \tRFN:      1
#  Unf...     1
# Name: count, Length: 582, dtype: int64, 'GarageQual': GarageQual
# TA        35
#  TA       29
# >TA       29
# TA:       25
# ta        25
#           ..
# ;Ta...     1
# !GD<       1
# ...ta!     1
# <Fa;       1
# :Ta;       1
# Name: count, Length: 331, dtype: int64, 'GarageCond': GarageCond
# TA       42
# <TA      32
# TA\t     28
# Ta       26
# :TA      25
#          ..
# !Gd!      1
# fa<       1
# ?TA!      1
# po?       1
# \tta<     1
# Name: count, Length: 296, dtype: int64, 'PavedDrive': PavedDrive
# Y       57
# .Y      46
# ;Y      42
# Y       42
# Y?      41
#         ..
# :Y       1
# ?Y?      1
# :n\t     1
# ;p       1
# :P;      1
# Name: count, Length: 249, dtype: int64, 'SaleType': SaleType
# WD        39
# :WD       26
# WD\t      23
# ;WD       23
# <WD       22
#           ..
# ;wd:       1
# :NEW       1
# \twd       1
# <New\t     1
# ;Wd...     1
# Name: count, Length: 389, dtype: int64, 'SaleCondition': SaleCondition
# NORMAL      20
# NORMAL\t    18
# normal?     17
# normal.     15
# NORMAL.     15
#             ..
# <NORMal      1
# >normal!     1
# FAMILY;      1
# PARTIAL      1
# <partial     1
# Name: count, Length: 626, dtype: int64}
#
#
# === Пример: распределение значений в колонке 'LotShape' ===
# <class 'pandas.core.series.Series'>
# LotShape
# REG          18
# Reg          17
#  IR1         14
# Reg<         14
# !REG         14
#              ..
#  Ir1...       1
# ;reg.         1
# ir2\t         1
# ?reg...       1
# ...REG...     1
# Name: count, Length: 480, dtype: int64

# %% [markdown]
# ## Step 3 — Clean the string-based dataset to match the clean schema

# %%
import os
import re
import numpy as np
import pandas as pd

try:
    PATH_DIR
except NameError:
    PATH_DIR = "/content/drive/MyDrive/data"

try:
    load_data
except NameError:
    def load_data(filename: str):
        if not os.path.exists(filename):
            print(f"{filename} does not exist")
            return None
        try:
            return pd.read_csv(filename)
        except Exception:
            return pd.read_csv(filename, sep=';')


dirty_path = os.path.join(PATH_DIR, "dirty_str_house_prices.csv")
pd_dirty_raw = load_data(dirty_path)

clean_path = os.path.join(PATH_DIR, "clean_house_prices.csv")
pd_clean_ref = load_data(clean_path)

if pd_dirty_raw is not None and "Unnamed: 0" in pd_dirty_raw.columns:
    pd_dirty_raw = pd_dirty_raw.drop(columns=["Unnamed: 0"])


def _basic_clean_str(x: object) -> object:
    if pd.isna(x):
        return x
    s = str(x)
    s = s.replace('\t', ' ').replace('\n', ' ')
    s = s.strip(" .;:,-_/\\\t\n")
    s = re.sub(r"\s+", " ", s)
    return s

def _to_numeric_safely(series: pd.Series) -> pd.Series:

    raw = series.astype(str)
    cleaned = raw.str.replace(r"[^0-9\-\.,]", "", regex=True).str.replace(",", "", regex=False)
    nums = pd.to_numeric(cleaned, errors="coerce")
    return nums

def _norm_key(v: object) -> str:
    v = str(v)
    v = v.lower()
    v = re.sub(r"[^a-z0-9]+", "", v)
    return v

def dirty_data(data: pd.DataFrame, ref: pd.DataFrame) -> pd.DataFrame:
    if data is None or ref is None:
        return data

    df = data.copy()


    for c in df.columns:
        if df[c].dtype == "object":
            df[c] = df[c].map(_basic_clean_str)


    if "Id" in df.columns:
        df = df.set_index("Id", drop=True)
    if "Id" in ref.columns:
        ref = ref.set_index("Id", drop=True)

    out = df.copy()
    for c in out.columns:
        if c in ref.columns:
            if pd.api.types.is_numeric_dtype(ref[c]):
                out[c] = _to_numeric_safely(out[c])
            else:
                ref_vals = ref[c].dropna().astype(str).unique()
                ref_map = {_norm_key(rv): rv for rv in ref_vals}

                def map_to_ref(val):
                    if pd.isna(val):
                        return val
                    key = _norm_key(val)
                    return ref_map.get(key, str(val).strip().title())
                out[c] = out[c].apply(map_to_ref)
        else:

            pass


    common_cols = [c for c in ref.columns if c in out.columns]
    out = out[common_cols].copy()


    out = out.reset_index()
    return out

pd_dirty_cleaned = dirty_data(pd_dirty_raw, pd_clean_ref)

print("До очистки (грязный) — первые 5 строк:\n", pd_dirty_raw.head(), "\n")
print("После очистки — первые 5 строк:\n", pd_dirty_cleaned.head())
# Out:
# До очистки (грязный) — первые 5 строк:
#     Id MSZoning  Street LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  RoofStyle     RoofMatl    Exterior1st Exterior2nd MasVnrType  \
# 0   1      rl:   PAVE.     ;REg       \tlvl   AllPub.   InsidE:      gtl      COLLGCR<      norm;      NORM.     1fam   ?2story?   GABLE...     compshg!  ...Vinylsd...    Vinylsd.   Brkface>
# 1   2    ...RL   <PAVE    reg\t        Lvl;  AllPUb\t      FR2       Gtl<    veenker\t    ?FEedr.      ;norm    1FAM:    :1story  .GABLE...     CoMPSHG>        METALSD    metalsd      ?NOnE.
# 2   3     ;Rl    Pave      ir1?        LVL!   Allpub!  ?inside     ...Gtl     ?COLLGCR      !Norm     .norm>    !1fam    .2story      Gable  ...COMPSHG:       vinylsd.    ?Vinylsd   !brkface
# 3   4       rl   pave.     ;IR1        .Lvl  ;ALLPUB;   >Corner      ;GTL     .CRAWFOR       NORm      NORM:    1FAM>    2STORY<   \tgable.    !Compshg<       WD SDNG:    Wd shng;      :NONE
# 4   5    .rl\t  PaVE\t   Ir1...        Lvl<   !Allpub      ?fr2   .GTL...    ?NoRIdge>   ...NORM<      Norm;    1fam<    2SToRy<     GaBLe<     :compshg       :VINYLSD    VInYLSD?   ?Brkface
#
#   ExterQual ExterCond    Foundation BsmtQual  BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2    Heating HeatingQC CentralAir Electrical KitchenQual Functional GarageType GarageFinish GarageQual  \
# 0     GD...       TA<        pconc>    \tGd>       :TA        .no\t        ;Glq          UNF.      GASA<      \tEX         :Y     SBRKr         gd\t        TYP    AttChd<         .RFn       TA\t
# 1      ?Ta<        TA       >Cblock    ?GD\t       TA:           gd          Alq         ;Unf     ;GASA:       Ex         y\t    \tSBRKR         ta?       ;TYP    Attchd>        RFn\t       \tTa
# 2        gd       !TA       \tPCOnC     ;GD.      .TA          mn\t          GLQ       \tUNF;    GAsA...       ;Ex        Y\t     sbrkr<         .Gd     TyP...    Attchd;         ;RFN    \tTA...
# 3       Ta<      TA\t  ...BRKTIL...     .Ta       \tgd         >NO:          alq        :unf<     GaSA\t      :GD        Y...    \tSbrkr         Gd<       !TYP  DETCHD...         UNF?      \tTa;
# 4       :Gd       ta:       .pconc:     <Gd<  ...TA...           Av        ;glq!      :unf...  \tGASA...       ex!          y    \tSbrkr         GD;      <Typ>   Attchd\t        !rfn>       TA\t
#
#   GarageCond PavedDrive SaleType SaleCondition
# 0      \tTA<         y?      wd      \tNormal?
# 1      >TA\t        ;Y!      Wd        Normal.
# 2        TA           Y      WD;        NORMAL
# 3        ;Ta         .Y      wd.     ABNORML\t
# 4         Ta       \tY>     ?WD!       NoRmAl>
#
# После очистки — первые 5 строк:
#     Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# 0   1       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg     VinylSd     VinylSd    BrkFace        Gd
# 1   2       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg     MetalSd     MetalSd      ?None        TA
# 2   3       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg     VinylSd     VinylSd    BrkFace        Gd
# 3   4       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg     Wd Sdng     Wd Shng       None        TA
# 4   5       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg     VinylSd     VinylSd    BrkFace        Gd
#
#   ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 Heating HeatingQC CentralAir Electrical KitchenQual Functional GarageType GarageFinish GarageQual GarageCond  \
# 0        TA      PConc       Gd       TA           No          GLQ          Unf    GasA        Ex          Y      SBrkr          Gd        Typ     Attchd          RFn         TA         TA
# 1        TA     CBlock       Gd       TA           Gd          ALQ          Unf    GasA        Ex          Y      SBrkr          TA        Typ     Attchd          RFn         TA         TA
# 2        TA      PConc       Gd       TA           Mn          GLQ          Unf    GasA        Ex          Y      SBrkr          Gd        Typ     Attchd          RFn         TA         TA
# 3        TA     BrkTil       TA       Gd           No          ALQ          Unf    GasA        Gd          Y      SBrkr          Gd        Typ     Detchd          Unf         TA         TA
# 4        TA      PConc       Gd       TA           Av          GLQ          Unf    GasA        Ex          Y      SBrkr          Gd        Typ     Attchd          RFn         TA         TA
#
#   PavedDrive SaleType SaleCondition
# 0          Y       WD        Normal
# 1          Y       WD        Normal
# 2          Y       WD        Normal
# 3          Y       WD       Abnorml
# 4          Y       WD        Normal

# %% [markdown]
# ## Step 4 — Compare cleaned dirty data with the clean data

# %%
from google.colab import drive
drive.mount('/content/drive')

import os, re, glob
import numpy as np
import pandas as pd

CLEAN_CANDIDATES = ["clean_house_prices.csv", "num_house_prices.csv"]
DIRTY_CANDIDATES = ["dirty_str_house_prices.csv", "str_house_prices.csv"]

def find_in_drive(names):
    for name in names:
        matches = glob.glob(f"/content/drive/MyDrive/**/{name}", recursive=True)
        if matches:
            print(f"Found {name}: {matches[0]}")
            return matches[0]
    return None

clean_path = find_in_drive(CLEAN_CANDIDATES)
dirty_path = find_in_drive(DIRTY_CANDIDATES)

if clean_path is None or dirty_path is None:
    raise FileNotFoundError(
        "Не удалось найти один из файлов в Google Drive. "
        "Проверь точные имена файлов или положи их в MyDrive. "
        f"Искали: clean={CLEAN_CANDIDATES}, dirty={DIRTY_CANDIDATES}"
    )

def load_data(filename: str):
    if not os.path.exists(filename):
        print(f"{filename} does not exist")
        return None
    try:
        return pd.read_csv(filename)
    except Exception:
        return pd.read_csv(filename, sep=';')

pd_clean_ref = load_data(clean_path)
pd_dirty_raw = load_data(dirty_path)

if pd_dirty_raw is not None and "Unnamed: 0" in pd_dirty_raw.columns:
    pd_dirty_raw = pd_dirty_raw.drop(columns=["Unnamed: 0"])

def _basic_clean_str(x):
    if pd.isna(x): return x
    s = str(x).replace('\t',' ').replace('\n',' ')
    s = s.strip(" .;:,-_/\\\t\n")
    s = re.sub(r"\s+", " ", s)
    return s

def _to_numeric_safely(series: pd.Series) -> pd.Series:
    raw = series.astype(str)
    cleaned = raw.str.replace(r"[^0-9\-\.,]", "", regex=True).str.replace(",", "", regex=False)
    return pd.to_numeric(cleaned, errors="coerce")

def _norm_key(v):
    if pd.isna(v): return ""
    return re.sub(r"[^a-z0-9]+", "", str(v).lower())

def dirty_data(data: pd.DataFrame, ref: pd.DataFrame) -> pd.DataFrame:
    if data is None or ref is None:
        return data
    df = data.copy()

    for c in df.columns:
        if df[c].dtype == "object":
            df[c] = df[c].map(_basic_clean_str)

    if "Id" in df.columns: df = df.set_index("Id", drop=True)
    if "Id" in ref.columns: ref = ref.set_index("Id", drop=True)

    out = df.copy()
    for c in out.columns:
        if c in ref.columns:
            if pd.api.types.is_numeric_dtype(ref[c]):
                out[c] = _to_numeric_safely(out[c])
            else:
                ref_vals = ref[c].dropna().astype(str).str.strip().unique()
                ref_map = {_norm_key(rv): rv for rv in ref_vals}
                def map_to_ref(val):
                    if pd.isna(val): return val
                    key = _norm_key(val)
                    return ref_map.get(key, str(val).strip())
                out[c] = out[c].apply(map_to_ref)

    out = out[[c for c in ref.columns if c in out.columns]].copy().reset_index()
    return out

pd_dirty_cleaned = dirty_data(pd_dirty_raw, pd_clean_ref)

L = pd_clean_ref.set_index('Id')
R = pd_dirty_cleaned.set_index('Id')

common_cols = [c for c in L.columns if c in R.columns]
idx = L.index.intersection(R.index)
L = L.loc[idx, common_cols].copy()
R = R.loc[idx, common_cols].copy()


for c in common_cols:
    if pd.api.types.is_numeric_dtype(L[c]) or pd.api.types.is_numeric_dtype(R[c]):
        L[c] = pd.to_numeric(L[c], errors='coerce')
        R[c] = pd.to_numeric(R[c], errors='coerce')
    else:
        L[c] = L[c].astype(str).str.strip()
        R[c] = R[c].astype(str).str.strip()


eq_all = (L.eq(R)) | (L.isna() & R.isna())
overall_pct = 100.0 * eq_all.stack().mean()
print(f"Overall (%) same: {overall_pct:.6f}")

USE_COMMA_DECIMAL = True
print("\n(%) same")
for c in common_cols:
    col_eq = (L[c].eq(R[c])) | (L[c].isna() & R[c].isna())
    pct = 100.0 * float(col_eq.mean())
    val = f"{pct:.6f}"
    if USE_COMMA_DECIMAL:
        val = val.replace('.', ',')
    print(f"{c:<14} {val}")
# Out:
# Mounted at /content/drive
# Found clean_house_prices.csv: /content/drive/MyDrive/Colab Notebooks/clean_house_prices.csv
# Found dirty_str_house_prices.csv: /content/drive/MyDrive/Colab Notebooks/dirty_str_house_prices.csv
# Overall (%) same: 98.465896
#
# (%) same
# MSZoning       100,000000
# Street         99,925262
# LotShape       99,925262
# LandContour    99,925262
# Utilities      99,925262
# LotConfig      99,925262
# LandSlope      99,925262
# Neighborhood   99,925262
# Condition1     100,000000
# Condition2     99,925262
# BldgType       99,925262
# HouseStyle     99,925262
# RoofStyle      99,925262
# RoofMatl       99,925262
# Exterior1st    99,925262
# Exterior2nd    99,925262
# MasVnrType     44,245142
# ExterQual      100,000000
# ExterCond      99,925262
# Foundation     99,925262
# BsmtQual       99,925262
# BsmtCond       99,925262
# BsmtExposure   99,925262
# BsmtFinType1   99,925262
# BsmtFinType2   99,925262
# Heating        99,925262
# HeatingQC      99,925262
# CentralAir     99,925262
# Electrical     99,925262
# KitchenQual    99,925262
# Functional     99,925262
# GarageType     99,925262
# GarageFinish   99,925262
# GarageQual     99,925262
# GarageCond     99,925262
# PavedDrive     99,925262
# SaleType       99,925262
# SaleCondition  99,925262
